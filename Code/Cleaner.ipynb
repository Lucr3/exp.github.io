# %%
import pandas as pd

# %%
#df= pd.read_csv('../datasets/Middle_East_aggregated.csv')
#df= pd.read_csv('../datasets/number_of_reported_fatalities_by_country-year_as-of-12Dec2025.csv')
df = pd.read_csv('../datasets/deaths-in-armed-conflicts-by-country.csv')
#print(df.head())

# %%
#df = df[df['COUNTRY'] == 'Yemen']
df= df[df['Entity'] == 'Yemen']
#print(df.head())

# %%
#df.to_csv('../datasets/yemen_data_aggregated.csv', index=False)
#df.to_csv('../datasets/yemen_reported_fatalities.csv', index=False)
df.to_csv('../datasets/yemen_deaths_in_armed_conflicts.csv', index=False)
