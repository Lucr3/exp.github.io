# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/yemen_data_aggregated.csv')

# %%
df_unique = df[["EVENT_TYPE","SUB_EVENT_TYPE"]].drop_duplicates()
print(df_unique)
# Out:
#                        EVENT_TYPE                       SUB_EVENT_TYPE
# 0                         Battles                          Armed clash
# 398                       Battles         Government regains territory
# 438                       Battles  Non-state actor overtakes territory
# 466    Explosions/Remote violence                     Air/drone strike
# 562    Explosions/Remote violence                              Grenade
# 574    Explosions/Remote violence        Remote explosive/landmine/IED
# 765    Explosions/Remote violence    Shelling/artillery/missile attack
# 891    Explosions/Remote violence                         Suicide bomb
# 901                      Protests   Excessive force against protesters
# 904                      Protests                     Peaceful protest
# 1096                     Protests            Protest with intervention
# 1102                        Riots                         Mob violence
# ...

# %% [markdown]
# Quello che ci interessa in questi dati sono:
# 0                         Battles                          Armed clash
# 1      Explosions/Remote violence        Remote explosive/landmine/IED
# 7      Explosions/Remote violence    Shelling/artillery/missile attack
# 8                        Protests   Excessive force against protesters
# 478                      Protests            Protest with intervention
# 590                         Riots                         Mob violence
# 592                         Riots                Violent demonstration
# 984    Violence against civilians                               Attack
# 995    Explosions/Remote violence                              Grenade
# 2563   Violence against civilians       Abduction/forced disappearance
# 2594   Explosions/Remote violence                     Air/drone strike
# 5547   Explosions/Remote violence                         Suicide bomb
# 15438                     Battles         Government regains territory
# 15704  Explosions/Remote violence                      Chemical weapon

# %%
print(df["SUB_EVENT_TYPE"].value_counts())
print(df["EVENT_TYPE"].value_counts())
# Out:
# SUB_EVENT_TYPE
# Armed clash                            5722
# Air/drone strike                       4038
# Peaceful protest                       3921
# Shelling/artillery/missile attack      3284
# Attack                                 2692
# Remote explosive/landmine/IED          2342
# Change to group/activity               1417
# Abduction/forced disappearance         1057
# Government regains territory           1056
# Looting/property destruction           1044
# Disrupted weapons use                   971
# Other                                   549
# Arrests                                 467
# Violent demonstration                   291
# Grenade                                 256
# Non-state actor overtakes territory     252
# Non-violent transfer of territory       179
# Agreement                               142
# Protest with intervention               139
# Excessive force against protesters      105
# Headquarters or base established         75
# ...
